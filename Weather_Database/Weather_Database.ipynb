# %%
# Import the dependencies.
import json
import numpy as np
import pandas as pd
import requests

from citipy import citipy
from config import weather_api_key
from datetime import datetime

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Define the basic OpenWeatherMap URL
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          "Country": city_country,
                          "Date": city_date})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | eureka
# Processing Record 2 of Set 1 | skibbereen
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | bar-le-duc
# Processing Record 5 of Set 1 | tucuma
# Processing Record 6 of Set 1 | amnat charoen
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | amazar
# Processing Record 9 of Set 1 | taman
# Processing Record 10 of Set 1 | usinsk
# Processing Record 11 of Set 1 | castro
# Processing Record 12 of Set 1 | batemans bay
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | port alfred
# Processing Record 15 of Set 1 | butaritari
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | barcelona
# Processing Record 18 of Set 1 | yomitan
# City not found. Skipping...
# Processing Record 19 of Set 1 | makakilo city
# Processing Record 20 of Set 1 | cayenne
# Processing Record 21 of Set 1 | dikson
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | meyzieu
# Processing Record 25 of Set 1 | khatanga
# Processing Record 26 of Set 1 | severo-kurilsk
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | cherskiy
# Processing Record 31 of Set 1 | poum
# Processing Record 32 of Set 1 | qaanaaq
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 1 | manicore
# Processing Record 36 of Set 1 | ribeira grande
# Processing Record 37 of Set 1 | salalah
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | upernavik
# Processing Record 40 of Set 1 | villarrica
# Processing Record 41 of Set 1 | uige
# Processing Record 42 of Set 1 | sola
# Processing Record 43 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 44 of Set 1 | atambua
# Processing Record 45 of Set 1 | gat
# Processing Record 46 of Set 1 | egvekinot
# Processing Record 47 of Set 1 | carnarvon
# Processing Record 48 of Set 1 | cerritos
# Processing Record 49 of Set 1 | coos bay
# Processing Record 50 of Set 1 | puerto ayora
# Processing Record 1 of Set 2 | mar del plata
# Processing Record 2 of Set 2 | urgut
# Processing Record 3 of Set 2 | longyearbyen
# Processing Record 4 of Set 2 | yellowknife
# Processing Record 5 of Set 2 | port lincoln
# Processing Record 6 of Set 2 | middelburg
# Processing Record 7 of Set 2 | porecatu
# Processing Record 8 of Set 2 | saint george
# Processing Record 9 of Set 2 | bengkulu
# Processing Record 10 of Set 2 | mount gambier
# Processing Record 11 of Set 2 | aklavik
# Processing Record 12 of Set 2 | sept-iles
# Processing Record 13 of Set 2 | santa isabel
# Processing Record 14 of Set 2 | mitu
# Processing Record 15 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 2 | kapaa
# Processing Record 17 of Set 2 | luang prabang
# Processing Record 18 of Set 2 | saint-philippe
# Processing Record 19 of Set 2 | cape town
# Processing Record 20 of Set 2 | muros
# Processing Record 21 of Set 2 | mehamn
# Processing Record 22 of Set 2 | notse
# Processing Record 23 of Set 2 | chokurdakh
# Processing Record 24 of Set 2 | tezu
# Processing Record 25 of Set 2 | faya
# Processing Record 26 of Set 2 | kununurra
# Processing Record 27 of Set 2 | kapoeta
# Processing Record 28 of Set 2 | san jeronimo
# Processing Record 29 of Set 2 | kokopo
# Processing Record 30 of Set 2 | punta arenas
# Processing Record 31 of Set 2 | susuman
# Processing Record 32 of Set 2 | hermanus
# Processing Record 33 of Set 2 | el sauce
# Processing Record 34 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 35 of Set 2 | chuy
# Processing Record 36 of Set 2 | faanui
# Processing Record 37 of Set 2 | dingle
# Processing Record 38 of Set 2 | kahului
# Processing Record 39 of Set 2 | laurel
# Processing Record 40 of Set 2 | tuktoyaktuk
# Processing Record 41 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 42 of Set 2 | jimma
# Processing Record 43 of Set 2 | piedras negras
# Processing Record 44 of Set 2 | lufilufi
# Processing Record 45 of Set 2 | nikolskoye
# Processing Record 46 of Set 2 | nola
# Processing Record 47 of Set 2 | pisco
# Processing Record 48 of Set 2 | kirkuk
# Processing Record 49 of Set 2 | hithadhoo
# Processing Record 50 of Set 2 | constitucion
# Processing Record 1 of Set 3 | nhulunbuy
# Processing Record 2 of Set 3 | guerrero negro
# Processing Record 3 of Set 3 | pevek
# Processing Record 4 of Set 3 | balkanabat
# Processing Record 5 of Set 3 | tiksi
# Processing Record 6 of Set 3 | fairbanks
# Processing Record 7 of Set 3 | kodiak
# Processing Record 8 of Set 3 | omutinskoye
# City not found. Skipping...
# Processing Record 9 of Set 3 | san andres
# Processing Record 10 of Set 3 | cozumel
# Processing Record 11 of Set 3 | mocorito
# Processing Record 12 of Set 3 | cukai
# Processing Record 13 of Set 3 | inhambupe
# Processing Record 14 of Set 3 | saint-georges
# Processing Record 15 of Set 3 | isangel
# Processing Record 16 of Set 3 | airai
# Processing Record 17 of Set 3 | kaitangata
# Processing Record 18 of Set 3 | mastic beach
# Processing Record 19 of Set 3 | xianyang
# Processing Record 20 of Set 3 | talnakh
# Processing Record 21 of Set 3 | waipawa
# Processing Record 22 of Set 3 | staryy nadym
# Processing Record 23 of Set 3 | sambava
# Processing Record 24 of Set 3 | thunder bay
# Processing Record 25 of Set 3 | zolotukhino
# Processing Record 26 of Set 3 | oskaloosa
# Processing Record 27 of Set 3 | buon me thuot
# City not found. Skipping...
# Processing Record 28 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 3 | vila velha
# Processing Record 30 of Set 3 | torbay
# Processing Record 31 of Set 3 | tautira
# Processing Record 32 of Set 3 | narsaq
# Processing Record 33 of Set 3 | berlevag
# Processing Record 34 of Set 3 | bredasdorp
# Processing Record 35 of Set 3 | komsomolskiy
# Processing Record 36 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 3 | ambon
# Processing Record 38 of Set 3 | te anau
# Processing Record 39 of Set 3 | bilibino
# Processing Record 40 of Set 3 | puerto madryn
# Processing Record 41 of Set 3 | thurso
# Processing Record 42 of Set 3 | leningradskiy
# Processing Record 43 of Set 3 | quelimane
# Processing Record 44 of Set 3 | launceston
# Processing Record 45 of Set 3 | bowmore
# Processing Record 46 of Set 3 | isla mujeres
# Processing Record 47 of Set 3 | arraial do cabo
# Processing Record 48 of Set 3 | east london
# Processing Record 49 of Set 3 | ust-ilimsk
# Processing Record 50 of Set 3 | northam
# Processing Record 1 of Set 4 | sergeyevka
# Processing Record 2 of Set 4 | rawson
# Processing Record 3 of Set 4 | georgetown
# Processing Record 4 of Set 4 | avera
# Processing Record 5 of Set 4 | vaasa
# Processing Record 6 of Set 4 | kampot
# Processing Record 7 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 4 | jamestown
# Processing Record 9 of Set 4 | new norfolk
# Processing Record 10 of Set 4 | tual
# Processing Record 11 of Set 4 | khorinsk
# Processing Record 12 of Set 4 | barrow
# Processing Record 13 of Set 4 | mchinji
# Processing Record 14 of Set 4 | manaus
# Processing Record 15 of Set 4 | vostok
# Processing Record 16 of Set 4 | hilo
# Processing Record 17 of Set 4 | dagana
# Processing Record 18 of Set 4 | bethel
# Processing Record 19 of Set 4 | eucaliptus
# Processing Record 20 of Set 4 | shilka
# Processing Record 21 of Set 4 | khilok
# Processing Record 22 of Set 4 | westport
# Processing Record 23 of Set 4 | cabo san lucas
# Processing Record 24 of Set 4 | antsohihy
# Processing Record 25 of Set 4 | provideniya
# Processing Record 26 of Set 4 | bridgetown
# Processing Record 27 of Set 4 | flagstaff
# Processing Record 28 of Set 4 | lebu
# Processing Record 29 of Set 4 | clyde river
# Processing Record 30 of Set 4 | falealupo
# City not found. Skipping...
# Processing Record 31 of Set 4 | souillac
# Processing Record 32 of Set 4 | tuatapere
# Processing Record 33 of Set 4 | weiser
# Processing Record 34 of Set 4 | san quintin
# Processing Record 35 of Set 4 | laguna
# Processing Record 36 of Set 4 | gizo
# Processing Record 37 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 4 | idukki
# Processing Record 39 of Set 4 | krasnyy chikoy
# Processing Record 40 of Set 4 | bambous virieux
# Processing Record 41 of Set 4 | lompoc
# Processing Record 42 of Set 4 | okhotsk
# Processing Record 43 of Set 4 | ahipara
# Processing Record 44 of Set 4 | grindavik
# Processing Record 45 of Set 4 | srednekolymsk
# Processing Record 46 of Set 4 | port keats
# Processing Record 47 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 4 | uribia
# Processing Record 49 of Set 4 | dandong
# Processing Record 50 of Set 4 | tshela
# Processing Record 1 of Set 5 | cidreira
# Processing Record 2 of Set 5 | parrita
# Processing Record 3 of Set 5 | mercedes
# Processing Record 4 of Set 5 | dunedin
# Processing Record 5 of Set 5 | mahebourg
# Processing Record 6 of Set 5 | novikovo
# Processing Record 7 of Set 5 | anadyr
# Processing Record 8 of Set 5 | tasiilaq
# Processing Record 9 of Set 5 | porkhov
# Processing Record 10 of Set 5 | victoria
# Processing Record 11 of Set 5 | comodoro rivadavia
# Processing Record 12 of Set 5 | turukhansk
# Processing Record 13 of Set 5 | aban
# Processing Record 14 of Set 5 | kuusamo
# Processing Record 15 of Set 5 | verkhnevilyuysk
# Processing Record 16 of Set 5 | saskylakh
# Processing Record 17 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 5 | port elizabeth
# Processing Record 19 of Set 5 | portland
# Processing Record 20 of Set 5 | sao filipe
# Processing Record 21 of Set 5 | lata
# Processing Record 22 of Set 5 | brewster
# Processing Record 23 of Set 5 | sorland
# Processing Record 24 of Set 5 | porto real
# Processing Record 25 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 5 | prince rupert
# Processing Record 27 of Set 5 | alice springs
# Processing Record 28 of Set 5 | yate
# Processing Record 29 of Set 5 | bilma
# Processing Record 30 of Set 5 | katsuura
# Processing Record 31 of Set 5 | springbok
# Processing Record 32 of Set 5 | sitka
# Processing Record 33 of Set 5 | ouallam
# Processing Record 34 of Set 5 | lorengau
# Processing Record 35 of Set 5 | gao
# Processing Record 36 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 5 | hasaki
# Processing Record 38 of Set 5 | pochutla
# Processing Record 39 of Set 5 | tomatlan
# Processing Record 40 of Set 5 | atar
# Processing Record 41 of Set 5 | charqueada
# Processing Record 42 of Set 5 | taoudenni
# Processing Record 43 of Set 5 | new richmond
# Processing Record 44 of Set 5 | hamilton
# Processing Record 45 of Set 5 | saint anthony
# Processing Record 46 of Set 5 | lisakovsk
# Processing Record 47 of Set 5 | ugoofaaru
# Processing Record 48 of Set 5 | leshukonskoye
# Processing Record 49 of Set 5 | korem
# Processing Record 50 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 6 | thano bula khan
# City not found. Skipping...
# Processing Record 2 of Set 6 | aripuana
# Processing Record 3 of Set 6 | maniitsoq
# Processing Record 4 of Set 6 | valparaiso
# Processing Record 5 of Set 6 | bend
# Processing Record 6 of Set 6 | los altos hills
# Processing Record 7 of Set 6 | thompson
# Processing Record 8 of Set 6 | krasnyy kut
# Processing Record 9 of Set 6 | abha
# Processing Record 10 of Set 6 | turinskaya sloboda
# Processing Record 11 of Set 6 | cherlak
# Processing Record 12 of Set 6 | bandarbeyla
# Processing Record 13 of Set 6 | luganville
# Processing Record 14 of Set 6 | am timan
# Processing Record 15 of Set 6 | warwick
# Processing Record 16 of Set 6 | trinidad
# Processing Record 17 of Set 6 | ponta do sol
# Processing Record 18 of Set 6 | cody
# Processing Record 19 of Set 6 | alugan
# Processing Record 20 of Set 6 | zyryanka
# Processing Record 21 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 6 | belyy yar
# Processing Record 23 of Set 6 | dudinka
# Processing Record 24 of Set 6 | balatero
# Processing Record 25 of Set 6 | chicama
# Processing Record 26 of Set 6 | leh
# Processing Record 27 of Set 6 | polunochnoye
# Processing Record 28 of Set 6 | neyshabur
# Processing Record 29 of Set 6 | carbondale
# Processing Record 30 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 31 of Set 6 | qasigiannguit
# Processing Record 32 of Set 6 | jalalabad
# Processing Record 33 of Set 6 | la ronge
# Processing Record 34 of Set 6 | burica
# City not found. Skipping...
# Processing Record 35 of Set 6 | necochea
# Processing Record 36 of Set 6 | ukmerge
# Processing Record 37 of Set 6 | grants
# Processing Record 38 of Set 6 | ixtapa
# Processing Record 39 of Set 6 | bajil
# Processing Record 40 of Set 6 | kutum
# Processing Record 41 of Set 6 | rahuri
# Processing Record 42 of Set 6 | husavik
# Processing Record 43 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 44 of Set 6 | leninsk-kuznetskiy
# Processing Record 45 of Set 6 | ilulissat
# Processing Record 46 of Set 6 | marquette
# Processing Record 47 of Set 6 | adrar
# Processing Record 48 of Set 6 | baglung
# Processing Record 49 of Set 6 | gamba
# Processing Record 50 of Set 6 | saint-pierre
# Processing Record 1 of Set 7 | havoysund
# Processing Record 2 of Set 7 | karakendzha
# City not found. Skipping...
# Processing Record 3 of Set 7 | ngunguru
# Processing Record 4 of Set 7 | qui nhon
# Processing Record 5 of Set 7 | henties bay
# Processing Record 6 of Set 7 | helena
# Processing Record 7 of Set 7 | hatillo
# Processing Record 8 of Set 7 | champerico
# Processing Record 9 of Set 7 | kieta
# Processing Record 10 of Set 7 | pueblo nuevo
# Processing Record 11 of Set 7 | pampierstad
# Processing Record 12 of Set 7 | codrington
# Processing Record 13 of Set 7 | sakaiminato
# Processing Record 14 of Set 7 | nanortalik
# Processing Record 15 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 7 | padang
# Processing Record 17 of Set 7 | sommerda
# Processing Record 18 of Set 7 | sao joao da barra
# Processing Record 19 of Set 7 | udachnyy
# Processing Record 20 of Set 7 | noumea
# Processing Record 21 of Set 7 | khormuj
# City not found. Skipping...
# Processing Record 22 of Set 7 | santiago de cao
# Processing Record 23 of Set 7 | los llanos de aridane
# Processing Record 24 of Set 7 | mineiros
# Processing Record 25 of Set 7 | esperance
# Processing Record 26 of Set 7 | sokoto
# Processing Record 27 of Set 7 | catamarca
# Processing Record 28 of Set 7 | caceres
# Processing Record 29 of Set 7 | allanmyo
# City not found. Skipping...
# Processing Record 30 of Set 7 | tilichiki
# Processing Record 31 of Set 7 | broken hill
# Processing Record 32 of Set 7 | yarada
# Processing Record 33 of Set 7 | port hardy
# Processing Record 34 of Set 7 | kavieng
# Processing Record 35 of Set 7 | ponta delgada
# Processing Record 36 of Set 7 | kirakira
# Processing Record 37 of Set 7 | luderitz
# Processing Record 38 of Set 7 | marawi
# Processing Record 39 of Set 7 | nome
# Processing Record 40 of Set 7 | palmerston north
# Processing Record 41 of Set 7 | norman wells
# Processing Record 42 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 43 of Set 7 | serabu
# Processing Record 44 of Set 7 | bathsheba
# Processing Record 45 of Set 7 | gremyachye
# City not found. Skipping...
# Processing Record 46 of Set 7 | belgrade
# Processing Record 47 of Set 7 | haines junction
# Processing Record 48 of Set 7 | mogadishu
# Processing Record 49 of Set 7 | achikulak
# Processing Record 50 of Set 7 | omboue
# Processing Record 1 of Set 8 | ende
# Processing Record 2 of Set 8 | rio grande
# Processing Record 3 of Set 8 | vestmanna
# Processing Record 4 of Set 8 | rapla
# Processing Record 5 of Set 8 | impfondo
# Processing Record 6 of Set 8 | ordzhonikidze
# Processing Record 7 of Set 8 | chapais
# Processing Record 8 of Set 8 | kungurtug
# Processing Record 9 of Set 8 | porto santo
# Processing Record 10 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 8 | naberera
# Processing Record 12 of Set 8 | chernyshevskiy
# Processing Record 13 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 8 | manzil jamil
# City not found. Skipping...
# Processing Record 15 of Set 8 | pacific grove
# Processing Record 16 of Set 8 | desa
# Processing Record 17 of Set 8 | igarka
# Processing Record 18 of Set 8 | vardo
# Processing Record 19 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 20 of Set 8 | bandiagara
# Processing Record 21 of Set 8 | alofi
# Processing Record 22 of Set 8 | north platte
# Processing Record 23 of Set 8 | maku
# Processing Record 24 of Set 8 | dutse
# Processing Record 25 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 8 | boden
# Processing Record 28 of Set 8 | kruisfontein
# Processing Record 29 of Set 8 | tambo
# Processing Record 30 of Set 8 | santo tomas
# Processing Record 31 of Set 8 | vung tau
# Processing Record 32 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 8 | perove
# Processing Record 34 of Set 8 | aksu
# Processing Record 35 of Set 8 | saint-augustin
# Processing Record 36 of Set 8 | manbij
# Processing Record 37 of Set 8 | shetpe
# Processing Record 38 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 39 of Set 8 | bukama
# Processing Record 40 of Set 8 | terra rica
# Processing Record 41 of Set 8 | beihai
# Processing Record 42 of Set 8 | hambantota
# Processing Record 43 of Set 8 | broome
# Processing Record 44 of Set 8 | winslow
# Processing Record 45 of Set 8 | solano
# Processing Record 46 of Set 8 | coquimbo
# Processing Record 47 of Set 8 | sharan
# Processing Record 48 of Set 8 | hofn
# Processing Record 49 of Set 8 | marzuq
# Processing Record 50 of Set 8 | normandin
# Processing Record 1 of Set 9 | roma
# Processing Record 2 of Set 9 | yanam
# Processing Record 3 of Set 9 | manado
# Processing Record 4 of Set 9 | kabansk
# Processing Record 5 of Set 9 | chabahar
# Processing Record 6 of Set 9 | emporia
# Processing Record 7 of Set 9 | constanta
# Processing Record 8 of Set 9 | boa vista
# Processing Record 9 of Set 9 | fountain hills
# Processing Record 10 of Set 9 | kosh-agach
# Processing Record 11 of Set 9 | lasa
# Processing Record 12 of Set 9 | vila franca do campo
# Processing Record 13 of Set 9 | serik
# Processing Record 14 of Set 9 | lerici
# Processing Record 15 of Set 9 | chumikan
# Processing Record 16 of Set 9 | knyaze-volkonskoye
# Processing Record 17 of Set 9 | kang
# Processing Record 18 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 9 | doctor arroyo
# Processing Record 20 of Set 9 | saldanha
# Processing Record 21 of Set 9 | ancud
# Processing Record 22 of Set 9 | ulladulla
# Processing Record 23 of Set 9 | nioro
# Processing Record 24 of Set 9 | sangar
# Processing Record 25 of Set 9 | sao miguel
# Processing Record 26 of Set 9 | mountain home
# Processing Record 27 of Set 9 | kumluca
# Processing Record 28 of Set 9 | zamosc
# Processing Record 29 of Set 9 | quatre cocos
# Processing Record 30 of Set 9 | zhigansk
# Processing Record 31 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 9 | union
# Processing Record 33 of Set 9 | balkhash
# Processing Record 34 of Set 9 | hobyo
# Processing Record 35 of Set 9 | whitehorse
# Processing Record 36 of Set 9 | dabakala
# Processing Record 37 of Set 9 | palmer
# Processing Record 38 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 39 of Set 9 | tres arroyos
# Processing Record 40 of Set 9 | anloga
# Processing Record 41 of Set 9 | caravelas
# Processing Record 42 of Set 9 | bozeman
# Processing Record 43 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 9 | yerbogachen
# Processing Record 45 of Set 9 | deep river
# Processing Record 46 of Set 9 | tamale
# Processing Record 47 of Set 9 | kerman
# Processing Record 48 of Set 9 | sobolevo
# Processing Record 49 of Set 9 | koumac
# Processing Record 50 of Set 9 | lianzhou
# Processing Record 1 of Set 10 | guymon
# Processing Record 2 of Set 10 | bindi
# Processing Record 3 of Set 10 | lagoa
# Processing Record 4 of Set 10 | assiniboia
# Processing Record 5 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 10 | ilebo
# Processing Record 7 of Set 10 | mandalgovi
# Processing Record 8 of Set 10 | morros
# Processing Record 9 of Set 10 | san patricio
# Processing Record 10 of Set 10 | presidente epitacio
# Processing Record 11 of Set 10 | whitecourt
# Processing Record 12 of Set 10 | harper
# Processing Record 13 of Set 10 | juegang
# Processing Record 14 of Set 10 | pokhara
# Processing Record 15 of Set 10 | la rioja
# Processing Record 16 of Set 10 | santa maria
# Processing Record 17 of Set 10 | sorong
# Processing Record 18 of Set 10 | manali
# Processing Record 19 of Set 10 | charters towers
# Processing Record 20 of Set 10 | najran
# Processing Record 21 of Set 10 | sinnamary
# Processing Record 22 of Set 10 | taltal
# Processing Record 23 of Set 10 | warrnambool
# Processing Record 24 of Set 10 | przhevalskoye
# Processing Record 25 of Set 10 | dawson creek
# Processing Record 26 of Set 10 | ndioum
# Processing Record 27 of Set 10 | viedma
# Processing Record 28 of Set 10 | yulara
# Processing Record 29 of Set 10 | togur
# Processing Record 30 of Set 10 | itoman
# Processing Record 31 of Set 10 | antalaha
# Processing Record 32 of Set 10 | plettenberg bay
# Processing Record 33 of Set 10 | rafai
# Processing Record 34 of Set 10 | port moresby
# Processing Record 35 of Set 10 | ipswich
# Processing Record 36 of Set 10 | steinen
# Processing Record 37 of Set 10 | aswan
# Processing Record 38 of Set 10 | tessalit
# Processing Record 39 of Set 10 | mazagao
# Processing Record 40 of Set 10 | maamba
# Processing Record 41 of Set 10 | college
# Processing Record 42 of Set 10 | port hedland
# Processing Record 43 of Set 10 | inhambane
# Processing Record 44 of Set 10 | serenje
# Processing Record 45 of Set 10 | shimoda
# Processing Record 46 of Set 10 | bosaso
# Processing Record 47 of Set 10 | moron
# Processing Record 48 of Set 10 | raudeberg
# Processing Record 49 of Set 10 | oranjemund
# Processing Record 50 of Set 10 | vao
# Processing Record 1 of Set 11 | kimbe
# Processing Record 2 of Set 11 | tiszaalpar
# Processing Record 3 of Set 11 | nendaz
# Processing Record 4 of Set 11 | sur
# Processing Record 5 of Set 11 | ginda
# Processing Record 6 of Set 11 | charkhi dadri
# Processing Record 7 of Set 11 | kasongo-lunda
# Processing Record 8 of Set 11 | pousat
# City not found. Skipping...
# Processing Record 9 of Set 11 | mafra
# Processing Record 10 of Set 11 | benjamin aceval
# Processing Record 11 of Set 11 | kunszentmiklos
# Processing Record 12 of Set 11 | kuah
# Processing Record 13 of Set 11 | vredendal
# Processing Record 14 of Set 11 | bereda
# Processing Record 15 of Set 11 | urengoy
# Processing Record 16 of Set 11 | eenhana
# Processing Record 17 of Set 11 | laiwu
# Processing Record 18 of Set 11 | marulanda
# Processing Record 19 of Set 11 | touros
# Processing Record 20 of Set 11 | livingston
# Processing Record 21 of Set 11 | panguna
# Processing Record 22 of Set 11 | zhezkazgan
# Processing Record 23 of Set 11 | kavaratti
# Processing Record 24 of Set 11 | iqaluit
# Processing Record 25 of Set 11 | ovalle
# Processing Record 26 of Set 11 | dubbo
# Processing Record 27 of Set 11 | acapulco
# Processing Record 28 of Set 11 | porto novo
# Processing Record 29 of Set 11 | ostersund
# Processing Record 30 of Set 11 | betki
# City not found. Skipping...
# Processing Record 31 of Set 11 | pizarro
# Processing Record 32 of Set 11 | mana
# Processing Record 33 of Set 11 | novobiryusinskiy
# Processing Record 34 of Set 11 | nagar
# Processing Record 35 of Set 11 | bud
# Processing Record 36 of Set 11 | seoul
# Processing Record 37 of Set 11 | porto seguro
# Processing Record 38 of Set 11 | umm ruwabah
# City not found. Skipping...
# Processing Record 39 of Set 11 | rorvik
# Processing Record 40 of Set 11 | kandalaksha
# Processing Record 41 of Set 11 | brae
# Processing Record 42 of Set 11 | levelland
# Processing Record 43 of Set 11 | fortuna
# Processing Record 44 of Set 11 | shchelyayur
# City not found. Skipping...
# Processing Record 45 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 46 of Set 11 | norsup
# Processing Record 47 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 11 | puerto escondido
# Processing Record 49 of Set 11 | skjervoy
# Processing Record 50 of Set 11 | trelew
# Processing Record 1 of Set 12 | bababe
# City not found. Skipping...
# Processing Record 2 of Set 12 | keti bandar
# Processing Record 3 of Set 12 | upington
# Processing Record 4 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 5 of Set 12 | kappeln
# Processing Record 6 of Set 12 | roald
# Processing Record 7 of Set 12 | belmonte
# Processing Record 8 of Set 12 | payson
# Processing Record 9 of Set 12 | guabito
# Processing Record 10 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 12 | nehe
# Processing Record 12 of Set 12 | boda
# Processing Record 13 of Set 12 | hami
# Processing Record 14 of Set 12 | boton
# Processing Record 15 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 16 of Set 12 | pangai
# Processing Record 17 of Set 12 | lavrentiya
# Processing Record 18 of Set 12 | beloha
# Processing Record 19 of Set 12 | tarko-sale
# Processing Record 20 of Set 12 | bajo baudo
# City not found. Skipping...
# Processing Record 21 of Set 12 | sibolga
# Processing Record 22 of Set 12 | mezen
# Processing Record 23 of Set 12 | pedana
# Processing Record 24 of Set 12 | azovskaya
# Processing Record 25 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 26 of Set 12 | zhob
# Processing Record 27 of Set 12 | kargasok
# Processing Record 28 of Set 12 | develi
# Processing Record 29 of Set 12 | robertsport
# Processing Record 30 of Set 12 | nampula
# Processing Record 31 of Set 12 | australind
# Processing Record 32 of Set 12 | iquique
# Processing Record 33 of Set 12 | qaqortoq
# Processing Record 34 of Set 12 | kangaatsiaq
# Processing Record 35 of Set 12 | rondonopolis
# Processing Record 36 of Set 12 | pauini
# Processing Record 37 of Set 12 | jalu
# Processing Record 38 of Set 12 | safaga
# Processing Record 39 of Set 12 | businga
# Processing Record 40 of Set 12 | bin qirdan
# Processing Record 41 of Set 12 | stromness
# Processing Record 42 of Set 12 | arroyos y esteros
# Processing Record 43 of Set 12 | bandipur
# Processing Record 44 of Set 12 | jacareacanga
# Processing Record 45 of Set 12 | dourados
# Processing Record 46 of Set 12 | flin flon
# Processing Record 47 of Set 12 | verona
# Processing Record 48 of Set 12 | olafsvik
# Processing Record 49 of Set 12 | kencong
# Processing Record 50 of Set 12 | agadir
# Processing Record 1 of Set 13 | samarai
# Processing Record 2 of Set 13 | santa cruz de la palma
# Processing Record 3 of Set 13 | loikaw
# Processing Record 4 of Set 13 | yendi
# Processing Record 5 of Set 13 | shingu
# Processing Record 6 of Set 13 | mao
# Processing Record 7 of Set 13 | alta floresta
# Processing Record 8 of Set 13 | korla
# Processing Record 9 of Set 13 | guilin
# Processing Record 10 of Set 13 | yumen
# Processing Record 11 of Set 13 | erzin
# Processing Record 12 of Set 13 | oistins
# Processing Record 13 of Set 13 | sanquhar
# Processing Record 14 of Set 13 | dilla
# Processing Record 15 of Set 13 | karabuk
# Processing Record 16 of Set 13 | usatove
# Processing Record 17 of Set 13 | plymouth
# Processing Record 18 of Set 13 | batsfjord
# Processing Record 19 of Set 13 | coromandel
# Processing Record 20 of Set 13 | zacapu
# Processing Record 21 of Set 13 | samana
# Processing Record 22 of Set 13 | klaksvik
# Processing Record 23 of Set 13 | boyabat
# Processing Record 24 of Set 13 | arman
# Processing Record 25 of Set 13 | angleton
# Processing Record 26 of Set 13 | kaniama
# Processing Record 27 of Set 13 | along
# Processing Record 28 of Set 13 | namibe
# Processing Record 29 of Set 13 | victor harbor
# Processing Record 30 of Set 13 | orlea
# Processing Record 31 of Set 13 | ukiah
# Processing Record 32 of Set 13 | kismayo
# Processing Record 33 of Set 13 | atasu
# Processing Record 34 of Set 13 | ballina
# Processing Record 35 of Set 13 | honiara
# Processing Record 36 of Set 13 | moose factory
# Processing Record 37 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 38 of Set 13 | olinda
# Processing Record 39 of Set 13 | houma
# Processing Record 40 of Set 13 | izhma
# Processing Record 41 of Set 13 | jawhar
# Processing Record 42 of Set 13 | rudarpur
# Processing Record 43 of Set 13 | camacha
# Processing Record 44 of Set 13 | lagunillas
# Processing Record 45 of Set 13 | chokwe
# Processing Record 46 of Set 13 | atherton
# Processing Record 47 of Set 13 | beringovskiy
# Processing Record 48 of Set 13 | baruun-urt
# Processing Record 49 of Set 13 | parras
# City not found. Skipping...
# Processing Record 50 of Set 13 | talavera de la reina
# Processing Record 1 of Set 14 | bowen
# Processing Record 2 of Set 14 | panguipulli
# Processing Record 3 of Set 14 | baishishan
# Processing Record 4 of Set 14 | tecoanapa
# Processing Record 5 of Set 14 | veraval
# Processing Record 6 of Set 14 | tazovskiy
# Processing Record 7 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 14 | tomigusuku
# Processing Record 9 of Set 14 | bhera
# Processing Record 10 of Set 14 | kenai
# Processing Record 11 of Set 14 | lima
# Processing Record 12 of Set 14 | pangoa
# Processing Record 13 of Set 14 | evans
# Processing Record 14 of Set 14 | altay
# Processing Record 15 of Set 14 | port blair
# Processing Record 16 of Set 14 | geraldton
# Processing Record 17 of Set 14 | conway
# Processing Record 18 of Set 14 | kerteh
# City not found. Skipping...
# Processing Record 19 of Set 14 | sao raimundo das mangabeiras
# Processing Record 20 of Set 14 | orange walk
# Processing Record 21 of Set 14 | havre-saint-pierre
# Processing Record 22 of Set 14 | smithers
# Processing Record 23 of Set 14 | flinders
# Processing Record 24 of Set 14 | haverfordwest
# Processing Record 25 of Set 14 | wellington
# Processing Record 26 of Set 14 | marsa matruh
# Processing Record 27 of Set 14 | ugento
# Processing Record 28 of Set 14 | loiza
# Processing Record 29 of Set 14 | bongandanga
# Processing Record 30 of Set 14 | mareeba
# Processing Record 31 of Set 14 | gurskoye
# City not found. Skipping...
# Processing Record 32 of Set 14 | teshie
# Processing Record 33 of Set 14 | safford
# Processing Record 34 of Set 14 | namatanai
# Processing Record 35 of Set 14 | waddan
# Processing Record 36 of Set 14 | tura
# Processing Record 37 of Set 14 | fukue
# Processing Record 38 of Set 14 | karratha
# Processing Record 39 of Set 14 | verkhnyaya sysert
# Processing Record 40 of Set 14 | casablanca
# Processing Record 41 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 14 | hovd
# Processing Record 43 of Set 14 | araouane
# Processing Record 44 of Set 14 | grand gaube
# Processing Record 45 of Set 14 | methoni
# Processing Record 46 of Set 14 | lovington
# Processing Record 47 of Set 14 | rincon
# Processing Record 48 of Set 14 | itaqui
# Processing Record 49 of Set 14 | mangan
# Processing Record 50 of Set 14 | rovnoye
# Processing Record 1 of Set 15 | makat
# Processing Record 2 of Set 15 | rudbar
# Processing Record 3 of Set 15 | eha amufu
# Processing Record 4 of Set 15 | kristinehamn
# Processing Record 5 of Set 15 | kaeo
# Processing Record 6 of Set 15 | constantine
# Processing Record 7 of Set 15 | meulaboh
# Processing Record 8 of Set 15 | ambulu
# Processing Record 9 of Set 15 | jiayuguan
# Processing Record 10 of Set 15 | angoche
# Processing Record 11 of Set 15 | phangnga
# Processing Record 12 of Set 15 | presidencia roque saenz pena
# Processing Record 13 of Set 15 | yunyang
# Processing Record 14 of Set 15 | kormilovka
# Processing Record 15 of Set 15 | guadalajara
# Processing Record 16 of Set 15 | puruandiro
# Processing Record 17 of Set 15 | chibuto
# Processing Record 18 of Set 15 | joao pinheiro
# Processing Record 19 of Set 15 | bonnyville
# Processing Record 20 of Set 15 | washington
# Processing Record 21 of Set 15 | atoka
# Processing Record 22 of Set 15 | saint-joseph
# Processing Record 23 of Set 15 | ituverava
# Processing Record 24 of Set 15 | kayakent
# Processing Record 25 of Set 15 | meadow lake
# Processing Record 26 of Set 15 | tir pol
# City not found. Skipping...
# Processing Record 27 of Set 15 | coihaique
# Processing Record 28 of Set 15 | erdemli
# Processing Record 29 of Set 15 | ostrovnoy
# Processing Record 30 of Set 15 | aasiaat
# Processing Record 31 of Set 15 | feira de santana
# Processing Record 32 of Set 15 | okha
# Processing Record 33 of Set 15 | nouakchott
# Processing Record 34 of Set 15 | cutervo
# Processing Record 35 of Set 15 | svirstroy
# Processing Record 36 of Set 15 | moroni
# Processing Record 37 of Set 15 | moree
# Processing Record 38 of Set 15 | benguela
# Processing Record 39 of Set 15 | sailana
# Processing Record 40 of Set 15 | vilhena
# Processing Record 41 of Set 15 | astana
# Processing Record 42 of Set 15 | bokspits
# City not found. Skipping...
# Processing Record 43 of Set 15 | byron bay
# Processing Record 44 of Set 15 | buchanan
# Processing Record 45 of Set 15 | radece
# Processing Record 46 of Set 15 | aviles
# Processing Record 47 of Set 15 | sataua
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
# Update the column order
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
# Disply the new DataFrame
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Eureka      US  40.8021 -124.1637     54.00        72         100
# 1     Skibbereen      IE  51.5500   -9.2667     33.80        64          75
# 2        Ushuaia      AR -54.8000  -68.3000     64.40        59          40
# 3     Bar-Le-Duc      FR  48.7500    5.1667     32.00        80          90
# 4         Tucuma      BR  -0.1833  -50.0500     78.82        87          88
# 5  Amnat Charoen      TH  15.9167  104.7500     63.72        83         100
# 6         Albany      US  42.6001  -73.9662     28.00        87         100
# 7         Amazar      RU  53.8580  120.8750     -2.09        90          21
# 8          Taman      RU  45.2117   36.7161     48.20        81           0
# 9         Usinsk      RU  65.9939   57.5281    -24.12        87          97
#
#    Wind Speed Current Description
# 0        3.00     overcast clouds
# 1       20.71       broken clouds
# 2        4.61    scattered clouds
# 3        6.91     overcast clouds
# 4        7.83       moderate rain
# 5       17.49     overcast clouds
# 6        3.06          light snow
# 7        2.01          few clouds
# 8        8.95           clear sky
# 9        1.21     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
